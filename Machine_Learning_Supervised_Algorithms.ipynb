# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahma2015/Machine-Learning-Supervised-Algorithms/blob/main/Machine_Learning_Supervised_Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #In this Notebook, ML supervised algorithms are explained:

# %% [markdown]
# #1. Linear Regression:

# %% [markdown]
# -This model is represented by this equation: y = b0 + b1*x1 + b2*x2 + ... + bn*xn
#
# -The relation between a and y and may be positiove relation or negative relation
#
# -This is linear equation, we need to find weights of features (b1,b2,b3,...) and intercept with y-axis (b0) to get the best fit line that represents the realtion between x (features) and y (target).
#
# -The best fit line is the line which gives the min error between the real target and predicted target.

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ![lin.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Applications of Linear Regression Algorithm:

# %% [markdown]
# **Salary Prediction: Predicting employee salary depending on years of experience.
#
# **Sales Forecasting: Predicting future sales based on past sales data.
#
# **Exam Performance Prediction: Predicting exam degree depending on hours of study
#
# **Exam Performance Prediction: Predicting exam degree depending on time spend on social media platform
#
# **Real State Pricing: Predicting price of apartments depending on area of apartments

# %% [markdown]
# #Advantages:

# %% [markdown]
# 1-Easy and simple: easy to understand
#
# 2-Interpretability: You can get an understand the relation between x and y and how cofficients (weights) of inputs/feature values (x) affect on outcome/taregt (y)
#
# 3-Fast: fast to train

# %% [markdown]
# #Disadvantages:

# %% [markdown]
# 1-Assumes Linearity: May not perform well if the relationship between the features and the target variable is non-linear.
#
# 2-Sensitive to Outliers: Outliers can significantly impact the model's performance.(Outliers are data points that deviate significantly from the general trend or pattern of the data. They can be unusually high or low values.)

# %% [markdown]
# #Why Outliers affect linear regression algorithm?
